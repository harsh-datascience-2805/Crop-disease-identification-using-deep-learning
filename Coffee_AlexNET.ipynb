# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, ReLU
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 32
image_size = (224, 224)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2,  # Split 20% of data as validation set
    fill_mode='nearest'
)

# %%
train_generator = train_datagen.flow_from_directory(
    r"D:\Harsh\SIG\SEM 3\DL\Plant disease classification\Coffee",
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 840 images belonging to 3 classes.

# %%
valid_generator = train_datagen.flow_from_directory(
    r"D:\Harsh\SIG\SEM 3\DL\Plant disease classification\Coffee",
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 208 images belonging to 3 classes.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization

# %%
# Create a Sequential model
model = Sequential()

# Define the input shape (224x224x3 for AlexNet)
input_shape = (224, 224, 3)

# First convolutional layer
model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Second convolutional layer
model.add(Conv2D(256, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Third convolutional layer
model.add(Conv2D(384, (3, 3), activation='relu'))
model.add(BatchNormalization())

# Fourth convolutional layer
model.add(Conv2D(384, (3, 3), activation='relu'))
model.add(BatchNormalization())

# Fifth convolutional layer
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Flatten the output for fully connected layers
model.add(Flatten())

# First fully connected layer with dropout
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Second fully connected layer with dropout
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Output layer with the number of classes
model.add(Dense(3, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping criteria
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=valid_generator
    #,callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 155s 6s/step - loss: 1.0462 - accuracy: 0.5000 - val_loss: 1.0066 - val_accuracy: 0.3798
# Epoch 2/50
# 27/27 [==============================] - 149s 5s/step - loss: 1.0345 - accuracy: 0.5024 - val_loss: 1.1765 - val_accuracy: 0.3894
# Epoch 3/50
# 27/27 [==============================] - 149s 5s/step - loss: 0.9823 - accuracy: 0.5250 - val_loss: 1.0385 - val_accuracy: 0.4760
# Epoch 4/50
# 27/27 [==============================] - 151s 6s/step - loss: 0.9543 - accuracy: 0.5536 - val_loss: 0.9548 - val_accuracy: 0.5529
# Epoch 5/50
# 27/27 [==============================] - 166s 6s/step - loss: 0.9543 - accuracy: 0.5500 - val_loss: 1.1034 - val_accuracy: 0.5096
# Epoch 6/50
# 27/27 [==============================] - 149s 6s/step - loss: 0.9451 - accuracy: 0.5595 - val_loss: 0.9998 - val_accuracy: 0.5481
# Epoch 7/50
# 27/27 [==============================] - 147s 5s/step - loss: 0.8824 - accuracy: 0.5964 - val_loss: 1.1059 - val_accuracy: 0.4808
# Epoch 8/50
# 27/27 [==============================] - 172s 6s/step - loss: 0.9121 - accuracy: 0.5833 - val_loss: 2.0689 - val_accuracy: 0.4135
# Epoch 9/50
# 27/27 [==============================] - 181s 7s/step - loss: 0.8912 - accuracy: 0.5786 - val_loss: 1.0509 - val_accuracy: 0.5337
# Epoch 10/50
# 27/27 [==============================] - 165s 6s/step - loss: 0.9017 - accuracy: 0.5810 - val_loss: 2.4574 - val_accuracy: 0.4760
# Epoch 11/50
# 27/27 [==============================] - 144s 5s/step - loss: 0.8768 - accuracy: 0.6286 - val_loss: 2.1936 - val_accuracy: 0.4471
# Epoch 12/50
# 27/27 [==============================] - 134s 5s/step - loss: 0.8936 - accuracy: 0.6024 - val_loss: 1.1482 - val_accuracy: 0.5240
# Epoch 13/50
# 27/27 [==============================] - 179s 7s/step - loss: 0.8830 - accuracy: 0.6095 - val_loss: 1.1491 - val_accuracy: 0.4663
# Epoch 14/50
# 27/27 [==============================] - 149s 6s/step - loss: 0.8672 - accuracy: 0.6274 - val_loss: 2.9007 - val_accuracy: 0.4327
# Epoch 15/50
# 27/27 [==============================] - 155s 6s/step - loss: 0.7846 - accuracy: 0.6714 - val_loss: 1.6066 - val_accuracy: 0.5096
# Epoch 16/50
# 27/27 [==============================] - 160s 6s/step - loss: 0.7899 - accuracy: 0.6631 - val_loss: 1.4819 - val_accuracy: 0.5337
# Epoch 17/50
# 27/27 [==============================] - 160s 6s/step - loss: 0.8071 - accuracy: 0.6452 - val_loss: 1.1514 - val_accuracy: 0.5000
# Epoch 18/50
# 27/27 [==============================] - 150s 5s/step - loss: 0.8060 - accuracy: 0.6667 - val_loss: 1.6353 - val_accuracy: 0.4471
# Epoch 19/50
# 27/27 [==============================] - 165s 6s/step - loss: 0.8223 - accuracy: 0.6536 - val_loss: 1.1156 - val_accuracy: 0.5096
# Epoch 20/50
# 27/27 [==============================] - 151s 6s/step - loss: 0.7907 - accuracy: 0.6440 - val_loss: 1.3142 - val_accuracy: 0.5385
# Epoch 21/50
# 27/27 [==============================] - 163s 6s/step - loss: 0.7863 - accuracy: 0.6702 - val_loss: 3.8257 - val_accuracy: 0.4231
# Epoch 22/50
# 27/27 [==============================] - 153s 6s/step - loss: 0.7854 - accuracy: 0.6643 - val_loss: 2.0149 - val_accuracy: 0.4567
# Epoch 23/50
# 27/27 [==============================] - 159s 6s/step - loss: 0.7724 - accuracy: 0.6810 - val_loss: 1.5436 - val_accuracy: 0.5529
# Epoch 24/50
# 27/27 [==============================] - 148s 5s/step - loss: 0.6915 - accuracy: 0.7107 - val_loss: 3.3789 - val_accuracy: 0.4519
# Epoch 25/50
# 27/27 [==============================] - 167s 6s/step - loss: 0.7586 - accuracy: 0.6952 - val_loss: 1.3280 - val_accuracy: 0.5721
# Epoch 26/50
# 27/27 [==============================] - 145s 5s/step - loss: 0.7413 - accuracy: 0.6988 - val_loss: 0.9893 - val_accuracy: 0.6010
# Epoch 27/50
# 27/27 [==============================] - 156s 6s/step - loss: 0.7257 - accuracy: 0.6917 - val_loss: 1.9519 - val_accuracy: 0.4856
# Epoch 28/50
# 27/27 [==============================] - 155s 6s/step - loss: 0.7413 - accuracy: 0.6821 - val_loss: 0.8944 - val_accuracy: 0.6058
# Epoch 29/50
# 27/27 [==============================] - 154s 6s/step - loss: 0.6691 - accuracy: 0.7321 - val_loss: 1.1113 - val_accuracy: 0.5962
# Epoch 30/50
# 27/27 [==============================] - 153s 6s/step - loss: 0.7407 - accuracy: 0.6833 - val_loss: 0.9029 - val_accuracy: 0.5337
# Epoch 31/50
# 27/27 [==============================] - 155s 6s/step - loss: 0.7465 - accuracy: 0.6964 - val_loss: 0.8055 - val_accuracy: 0.7115
# Epoch 32/50
# 27/27 [==============================] - 155s 6s/step - loss: 0.7227 - accuracy: 0.7214 - val_loss: 2.4858 - val_accuracy: 0.4327
# Epoch 33/50
# 27/27 [==============================] - 155s 6s/step - loss: 0.7292 - accuracy: 0.6869 - val_loss: 0.8918 - val_accuracy: 0.6875
# Epoch 34/50
# 27/27 [==============================] - 160s 6s/step - loss: 0.6751 - accuracy: 0.7167 - val_loss: 1.0277 - val_accuracy: 0.6250
# Epoch 35/50
# 27/27 [==============================] - 157s 6s/step - loss: 0.6990 - accuracy: 0.6976 - val_loss: 0.8986 - val_accuracy: 0.6106
# Epoch 36/50
# 27/27 [==============================] - 165s 6s/step - loss: 0.7170 - accuracy: 0.7024 - val_loss: 1.0762 - val_accuracy: 0.5288
# Epoch 37/50
# 27/27 [==============================] - 150s 6s/step - loss: 0.6669 - accuracy: 0.7440 - val_loss: 1.2750 - val_accuracy: 0.6010
# Epoch 38/50
# 27/27 [==============================] - 165s 6s/step - loss: 0.7050 - accuracy: 0.7179 - val_loss: 1.3316 - val_accuracy: 0.4808
# Epoch 39/50
# 27/27 [==============================] - 144s 5s/step - loss: 0.6822 - accuracy: 0.7250 - val_loss: 1.9750 - val_accuracy: 0.2788
# Epoch 40/50
# 27/27 [==============================] - 160s 6s/step - loss: 0.7151 - accuracy: 0.7250 - val_loss: 0.7925 - val_accuracy: 0.6683
# Epoch 41/50
# 27/27 [==============================] - 150s 6s/step - loss: 0.6611 - accuracy: 0.7429 - val_loss: 0.7861 - val_accuracy: 0.6587
# Epoch 42/50
# 27/27 [==============================] - 164s 6s/step - loss: 0.6113 - accuracy: 0.7714 - val_loss: 1.6039 - val_accuracy: 0.6058
# Epoch 43/50
# 27/27 [==============================] - 146s 5s/step - loss: 0.6887 - accuracy: 0.7321 - val_loss: 0.9299 - val_accuracy: 0.6298
# Epoch 44/50
# 27/27 [==============================] - 157s 6s/step - loss: 0.7425 - accuracy: 0.6988 - val_loss: 0.9969 - val_accuracy: 0.6250
# Epoch 45/50
# 27/27 [==============================] - 144s 5s/step - loss: 0.6897 - accuracy: 0.7274 - val_loss: 1.0569 - val_accuracy: 0.6442
# Epoch 46/50
# 27/27 [==============================] - 155s 6s/step - loss: 0.6955 - accuracy: 0.7107 - val_loss: 2.1951 - val_accuracy: 0.3846
# Epoch 47/50
# 27/27 [==============================] - 104s 4s/step - loss: 0.7511 - accuracy: 0.7179 - val_loss: 0.8125 - val_accuracy: 0.6490
# Epoch 48/50
# 27/27 [==============================] - 57s 2s/step - loss: 0.6309 - accuracy: 0.7440 - val_loss: 1.1048 - val_accuracy: 0.5481
# Epoch 49/50
# 27/27 [==============================] - 58s 2s/step - loss: 0.6205 - accuracy: 0.7357 - val_loss: 0.7998 - val_accuracy: 0.6731
# Epoch 50/50
# 27/27 [==============================] - 58s 2s/step - loss: 0.6042 - accuracy: 0.7595 - val_loss: 1.1408 - val_accuracy: 0.6298

# %%
model.save(r"D:\Harsh\SIG\SEM 3\DL\Plant disease classification\coffee_alexnet.h5")

# %%
import matplotlib.pyplot as plt

# Get training and validation loss from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Get training and validation accuracy from the history object
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# Create subplots for loss and accuracy
plt.figure(figsize=(12, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss', color='blue', linestyle='--')
plt.plot(val_loss, label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss vs. Epochs')

# Plot training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Training Accuracy', color='blue', linestyle='--')
plt.plot(val_acc, label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy vs. Epochs')

# Show the plots
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = "D:\Harsh\SIG\SEM 3\DL\Plant disease classification\Coffee_Test\Rust.jpg"
img = load_img(image_path, target_size=(224,224))

# %%
img_array = img_to_array(img)

# %%
img_array = np.expand_dims(img_array, axis=0)

# %%
img_array = img_array / 255.0

# %%
predictions = model.predict(img_array)
predictions
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([[0.02343594, 0.47363806, 0.50292605]], dtype=float32)

# %%
predicted_class = np.argmax(predictions)
class_labels = ['Healthy', 'Spider Mite', 'Rust']
predicted_label = class_labels[predicted_class]

# %%
plt.imshow(img)
plt.title(f"Predicted Class: {predicted_label}")
plt.axis('off')
plt.show()
